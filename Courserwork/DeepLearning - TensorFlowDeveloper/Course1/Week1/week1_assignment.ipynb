# %% [markdown]
# ## Week 1 Assignment: Housing Prices
#
# <p>In this week's assingment we are asked to build a model based on a small Neural Network, capable of predicting the price of a house based on simple attributes</p>
#
# <p>From the original assignment we are given the following information about the pricing function of a house: A house has a base cost of 50k, and every additional bedroom adds a cost of 50k. This will make a 1 bedroom house cost 100k, and 2 bedroom house cost 150k and so on...
#
# We are here tasked with building a small neural network that can be used to predict the price of a house, given our selection of the number of bedrooms
# </p>

# %%
import tensorflow as tf 
import numpy as np

# %%
def house_model():

    #Define the input and output tensors with the values for houses with 1 p to 6 bedrooms
    xs = np.array([1,2,3,4,5,6], dtype=float)
    ys = np.array([100,150,200,250,300,350], dtype=float)

    #Define your model (should be a model with 1 dense layer and 1 unit)
    model = tf.keras.Sequential([tf.keras.layers.Dense(units=1, input_shape=[1])])

    #Compile your model
    #Set the optimizer to Stochastic Gradient Descent
    #Use Mean Squared Error as the loss function
    model.compile(optimizer='SGD', loss='MSE')

    #Train your model for 1000 epochs by feeding the i/o tensors 
    model.fit(xs,ys,epochs=1000)

    return model

# %%
#Now, lets train the model
model = house_model()
# Out:
# Epoch 1/1000
# 1/1 [==============================] - 0s 319ms/step - loss: 60872.3164
# Epoch 2/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 28305.6230
# Epoch 3/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 13231.8174
# Epoch 4/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 6254.2515
# Epoch 5/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 3023.8777
# Epoch 6/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1527.8213
# Epoch 7/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 834.4665
# Epoch 8/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 512.6346
# Epoch 9/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 362.7599
# Epoch 10/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 292.4787
# Epoch 11/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 259.0430
# Epoch 12/1000
# ...

# %%
#Here we can play around with a y-value and ask the model for predicting the price 
#of a house, based on the new value of y (ie. number of bedrooms)

new_y = 7
prediction = model.predict([new_y])[0]
print(prediction)
# Out:
# 1/1 [==============================] - 0s 31ms/step
# [400.59048]
